# %% [markdown]
# 1) A puzzle has multiple ways of reaching the end solution. Fig. 1 shows a graph that represents all possible
# routes to the solution. The starting point of the game is represented by A, the solution is represented by S.
# The other points in the graph are possible intermediary stages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) The graph in Fig. 1 is a visualisation of the problem.

# %% [markdown]
# (i) Identify the differences between a graph and a tree.

# %% [markdown]
#     According to Robin Winson (1972, 1996), a graph is a diagram representing points an lines, which points are called vertices or nodes and lines or links can be called edges.
#     Vertices are the end-points or a junction of edges, the degree of a vertex corresponds to the number of edges that meet at that end-point, this is diagrammatically represented in Fig. 1. Still according to the author, some intersections cannot be classified as a vertex because edges do not really cross each other, as example edges 2 and 7 represented in Fig 1. According to the overall graph theory acknoledged, the term walk is just a way of going to a vertex to another, and the term path is when a vertex does not appear more than once.
#     A tree is a connected type of graph with only one path connecting each pair of vertices, according to Robin Winson (1972, 1996), this graph has no cycles or loops. Trees respect a hierarchical structure, this structure has a vertex at the top, called root, which on the problem is presented by A.

# %% [markdown]
# (ii) Explain in detail how the graph is an abstraction of the problem.

# %% [markdown]
#      A graph is an effective abstraction for illustrating and resolving many issues, especially if such issues represent the links and relationships between different things. The presented problem for the game which points a start and end points can be clearly specified by a graph. The graph abstraction helps us to create and analyze complicated interactions across different areas. It helps a deeper understanding of this interactions within the system or issue by giving a high-level picture that represents the basic interaction and structural characteristics of the problem, allowing th use of a graph algorithms and simplifying problem-solving.

# %% [markdown]
# (iii) Identify the advantages of using a visualisation such as the one shown in Fig. 1.

# %% [markdown]
#     The advantage of using visualisation like Fig. 1 is that graphs are extremely visual, making it simple the understand and analyse complex relationships and structures such as data, networks and pathfinding for example (Geeksforgeeks, 2023).
#     Visualisation helps to get a better and clearer representation of the problem and its relationships, identifying clusters and patterns, understanding the connectivity between nodes and also identifying critical ones when necessary, as can help to enhance efficiency and find potential solutions to a problem.

# %% [markdown]
# (b) Demonstrate how Dijkstra’s algorithm would find the shortest path to the solution in Fig.1 through
# diagrams and written explanation of each stage.

# %%
import heapq

# %% [markdown]
# 2) The creator of the puzzle has been told that the A* algorithm is more efficient at finding the shortest path
# because it uses heuristics. Compare the performance of Dijkstra’s algorithm and the A* search algorithm,
# referring to heuristics, to find the shortest path to the problem by implementing both algorithms
# programmatically and comparing the solutions generated in Mark-down. Refer to the complexity of the
# algorithms and compare the actual time it takes for the solutions to be processed.
